# %% [markdown]
# # Taller 6 de MMAF
#
# ## A Ejercicios de repaso
#
#
# 1. Considere la función $f(x)=\dfrac{2 ^{x}}{7}$, grafique la función.
#
# 2. Grafique las funciones y describa que movimientos en el plano respecto a la gráfica de la función  $y=exp(2x)$
#
#  * $y=exp(-2x)$
#
#  * $y=-exp(2x)$
#
#  * $y=-exp(-2x)+6$
#
# 3. Intente gráficar la función $y=exp(10x)$ en el intervalo $[100,1000]$ ¡Que sucede?
#
# 4. La graficar la función $y=0.1^x$ porque decrece para valores de $x$ muy grandes
#
# 5. Grafique la función $y=\log_4(x)$
#
# 6. Resuelva las ecuaciones
#
#  - $ln(x^2-1)=2$
#
#  - $exp(x-1)=100$
#
# 7. Un biólogo está estudiando el crecimiento de una población de bacterias en un laboratorio. La cantidad de bacterias $N(t)$ después de $t$ horas sigue el modelo de crecimiento:
#
# $$
# N(t) = N_0 \cdot e^{kt}
# $$
#
# donde $N_0$ es la cantidad inicial de bacterias y $k$ es la tasa de crecimiento. Después de 5 horas, el biólogo observa que la población de bacterias se ha multiplicado por 16. Si la población inicial era de 100 bacterias, encuentra la tasa de crecimiento $k$.
#
# 8. Grafique las siguientes funciones y encuentre su dominio y rango:
#
#     - $y=e^x$
#     - $y=2^x$
#     - $y=\ln|x|$
#     - $y=\log_2\Big(\frac{x-2}{+3}\Big)$
#     - $y=e^{\frac{2x-4}{4x-5}}$
#
# 9. Un material radioactivo tiene una masa inicial de 200 g y se desintegra según el modelo:
# $$M(t) = 200 \cdot e^{-0.0231t}$$
# donde $t$ es el tiempo en años.
#
#  - Grafica la función $M(t)$ y encuentra su dominio y rango.
#  - ¿Cuánto tiempo tardará en desintegrarse el 90\% del material?
#  - ¿Cuál es la masa restante después de 10 años?
#
# 10. Una colonia de bacterias crece exponencialmente sin presencia de antibiótico según el modelo:
# $$
# B(t) = 50 \cdot e^{0.2t}
# $$.
#
# Y crece según el siguiente modelo con presencia de antibiótico:
# $$
# B_{\text{trat}}(t) = \frac{1000}{1 + 19 \cdot e^{-0.3t}}
# $$.
#
#  - **Graficar** ambas funciones en $t \in [0, 20]$ horas
#  - **Encontrar** el tiempo cuando $B_{\text{trat}}(t) = 500$ usando logaritmos
#  - **Comparar** las gráficas y explicar por qué el modelo con antibiótico es más realista
#
# 11. Un virus se propaga según:
# $$V(t) = \frac{10,000}{1 + 999 \cdot e^{-0.4t}}$$
# donde $V(t)$ = número de infectados, $t$ = tiempo en días
#
#  - **Graficar** $V(t)$ para $t \in [0, 30]$ días
#  - **Calcular** el día cuando el 50% de la población está infectada (5000 personas)
#  - **Interpretar** la asíntota horizontal biológicamente
#
# 12. Crecimiento de una planta bajo condiciones de luz
#
# Un investigador estudia el crecimiento en altura $H(t)$ (en cm) de una planta que sigue el modelo:
#
# $$H(t) = H_0 \, e^{kt}$$
#
# donde $H_0$ es la altura inicial y $k$ la tasa de crecimiento.
# Después de 10 días, la planta duplicó su altura. Si al inicio medía 8 cm:
#
#  - Encuentra la tasa de crecimiento $k$.
#  - Determina la altura de la planta después de 20 días.
#  - Grafica $H(t)$ en el intervalo $t \in [0, 25]$.
#  - Explica si el modelo sigue siendo realista si se prolonga el tiempo más allá de 100 días.
#
# 13. Enfriamiento de un café
#
# Una taza de café a $90^\circ$C se enfría en una habitación a $20^\circ$C según la ley de enfriamiento de Newton:
#
# $$T(t) = 20 + 70\, e^{-0.12t}$$
#
# donde $t$ es el tiempo en minutos.
#
#  - Grafica la función y determina su dominio y rango.
#  - ¿Qué temperatura tiene el café después de 10 minutos?
#  - ¿Cuánto tiempo tarda en llegar a $40^\circ$C? (usa logaritmos).
#  - Explica por qué este modelo es más realista que un modelo lineal de enfriamiento.
#
# 14. Propagación de un virus informático
#
# La cantidad de computadoras infectadas $I(t)$ en una red sigue el modelo logístico:
#
# $$I(t) = \frac{5000}{1 + 99\, e^{-0.6t}}$$
#
# donde $t$ es el tiempo en horas.
#
#  - Grafica $I(t)$ y $I'(t)$ para $t \in [0, 10]$.
#  - Determina el tiempo cuando el número de computadoras infectadas alcanza 2500.
#  - Interpreta los parámetros 5000, 99 y 0.6 en el contexto del problema.
#  - Compara con un modelo exponencial $J(t) = 50\,e^{0.6t}$ y explica cuál describe mejor una propagación real.
