# %% [markdown]
# # 8. Optimizando la distribución de recursos en comunidades afectadas por desastres naturales

# %% [markdown]
# ## 8.1 Contexto
#
# Colombia enfrenta diversos desastres naturales, como inundaciones, deslizamientos de tierra y terremotos, que afectan gravemente a las comunidades vulnerables. En situaciones de emergencia, uno de los mayores retos es garantizar una distribución rápida y eficiente de los recursos disponibles —como alimentos, agua, medicinas y refugios— hacia las zonas más afectadas.
#
# La Unidad Nacional para la Gestión del Riesgo de Desastres (UNGRD) busca mejorar los mecanismos de respuesta mediante el uso de algoritmos que optimicen la asignación y el transporte de recursos. Con el apoyo de tecnologías de la información y las comunicaciones (TIC), como drones y herramientas de analítica avanzada, se pretende desarrollar modelos que aseguren una atención oportuna y equitativa.
#
# El desafío consiste en diseñar y evaluar algoritmos que equilibren la rapidez de respuesta con el uso eficiente de los recursos, considerando las limitaciones logísticas y geográficas del territorio colombiano.

# %% [markdown]
# ![Gemini_Generated_Image_6yil836yil836yil.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 8.2 Tema
#
# Aplicaciones de sucesiones en el análisis de problemas de contexto.
#
# ## 8.3 Objetivo
#
# Analizar la eficiencia y comportamiento de algoritmos utilizados en la distribución de recursos durante emergencias humanitarias, empleando herramientas matemáticas basadas en sucesiones y límites.

# %% [markdown]
# ## 8.4 Actividad
#
# ### 8.4.1 Evolución de la complejidad algorítmica
#
# Dadas dos funciones que representan la complejidad de dos algoritmos diferentes en función del número de comunidades afectadas $n$:
#
# $$
# T(n) = 5n^2 + 10n + 3, \quad G(n) = 3n^2 + 15n + 2
# $$
#
# responda lo siguiente:
#
# a) Calcule el límite de la razón $\frac{T(n)}{G(n)}$ cuando $n$ tiende a infinito.
#
# b) Grafique la función $\frac{T(n)}{G(n)}$ y analice su comportamiento para grandes valores de $n$.
#
# ### 8.4.2 Velocidad de entrega de recursos
#
# La función
#
# $$
# V(n) = \frac{1000n}{n^2 + 100}
# $$
#
# describe la velocidad de entrega de recursos en función del número de comunidades afectadas $n$.
#
# a) Calcule el límite de $V(n)$ cuando $n$ tiende a infinito.
#
# b) Grafique la función $V(n)$ y analice su comportamiento para grandes valores de $n$.
#
# ### 8.4.3 Recursos entregados por comunidad
#
# La función
#
# $$
# R(n) = 50\log(n) - \frac{n}{100}
# $$
#
# modela la cantidad de recursos entregados por comunidad en función de los días transcurridos desde el inicio de la distribución $n$.
#
# a) Calcule el límite de $R(n)$ cuando $n$ tiende a infinito.
#
# b) Grafique la función $R(n)$ y analice cómo evoluciona la distribución de recursos a largo plazo.
#
# ### 8.4.4 Análisis de eficiencia algorítmica
#
# Considere que la eficiencia de un algoritmo de distribución de recursos está dada por la función
#
# $$
# D(n) = \frac{n^2}{\log(n)}
# $$
#
# donde $n$ representa el número de locaciones o nodos de distribución.
# Por otro lado, la necesidad de recursos en cada nodo se describe mediante
#
# $$
# R(n) = n\log(n)
# $$
#
# a) Analice el comportamiento de las funciones $D(n)$ y $R(n)$ conforme $n$ crece indefinidamente.
#
# b) Determine el límite
#
# $$
# \lim_{n \to \infty}\frac{D(n)}{R(n)}
# $$
#
# c) Interprete el resultado en términos de eficiencia del algoritmo cuando el número de nodos de distribución es muy grande.
# ¿El algoritmo sigue siendo eficiente a medida que aumenta $n$?
# ¿Qué estrategias podrían adoptarse para mejorar la eficiencia en estos escenarios?

# %% [markdown]
# ### 8.4.5 Jugando con el computador!
#
# #### **Pregunta global:**
#
# > La UNGRD busca garantizar que su algoritmo de distribución de recursos mantenga una eficiencia adecuada incluso cuando aumenta el número de nodos de distribución.
# >
# > La eficiencia relativa del algoritmo está dada por
# >
# > $$
# > E(n) = \frac{D(n)}{R(n)} = \frac{\frac{n^2}{\ln(n)}}{n,\ln(n)} = \frac{n}{[\ln(n)]^2}
# > $$
# >
# > ¿A partir de cuántos nodos de distribución $n$ la eficiencia relativa $E(n)$ supera un umbral crítico $T$ (por ejemplo, $T = 100$), indicando que el algoritmo **ya no escala adecuadamente**?
#
# Tu tarea consiste en determinar el **valor mínimo** de $n$ que cumple
#
# $$
# E(n) = \frac{n}{[\ln(n)]^2} \ge T
# $$
#
# para un umbral $T$ dado.
#
# ---
#
# 1. **Comprender el problema.**
#    Analiza el significado físico o práctico del umbral $T$ en el contexto de la distribución de recursos.
#    ¿Qué representa una eficiencia relativa alta? ¿Por qué podría ser un signo de ineficiencia o sobrecarga?
#
# 2. **Planear la solución.**
#    Describe los pasos que seguirás para determinar el valor mínimo de $n$ que satisface la desigualdad.
#    ¿Usarás aproximaciones analíticas, un método numérico o una simulación computacional?
#
# 3. **Ejecutar el plan.**
#    Implementa tu estrategia en Python para calcular el menor valor de $n$ tal que $E(n) \ge T$.
#
# 4. **Examinar la solución obtenida.**
#    Verifica si el resultado obtenido es coherente con el comportamiento esperado de $E(n)$.
#    ¿Cómo cambia la eficiencia al aumentar $n$?
#    ¿Qué implicaciones tiene este resultado para el diseño del algoritmo en escenarios con gran cantidad de nodos?

# %% [markdown]
# Las siguientes celdas te permitirá interactuar con los sliders para responder lo solicitado:

# %%
import requests
# URL del archivo
url = "https://raw.githubusercontent.com/abelalv/libreria_2025/refs/heads/main/MMAF.py"
# Descargar el archivo
response = requests.get(url)
with open('MMAF.py', 'w', encoding='utf-8') as file:
    file.write(response.text)

# %%
from MMAF import interactive_efficiency

#Ejecutar la vision interactiva
interactive_efficiency()
# Out:
# ...
# Output()
