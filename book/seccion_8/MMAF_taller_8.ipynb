# %% [markdown]
# # Taller 8 de MMAF
#
# ## A Ejercicios de aplicación
#
# 1. Dadas las funciones que modelan el tiempo de ejecución de dos algoritmos en función del número de comunidades afectadas $n$:
#    $$
#    T_1(n) = 3n^3 + 5n^2 + 7n, \quad T_2(n) = 6n^3 + 2n + 10
#    $$
#    - a) Calcule el límite de $\dfrac{T_1(n)}{T_2(n)}$ cuando $n \to \infty$.
#    - b) Interprete el resultado en términos de cuál algoritmo es más eficiente para grandes valores de $n$.
#    - c) Grafique ambas funciones en el rango $n \in [0,50]$ y compare sus crecimientos (Puede hacer uso de las herramientas presentadas en [MMAF\_python\_8.ipynb](https://colab.research.google.com/github/abelalv/PUJ_MMAF/blob/main/seccion_8/MMAF_python_8.ipynb).
#
#
# 2. La función
#    $$
#    V(n) = \frac{2000n}{n^2 + 400}
#    $$
#    representa la **velocidad promedio** (en unidades por hora) de entrega de recursos en función del número de comunidades afectadas $n$.
#    - a) Determine el límite de $V(n)$ cuando $n \to \infty$.
#    - b) Interprete el significado físico del resultado.
#    - c) Grafique $V(n)$ y comente su tendencia para grandes $n$ (Puede hacer uso de las herramientas presentadas en [MMAF\_python\_8.ipynb](https://colab.research.google.com/github/abelalv/PUJ_MMAF/blob/main/seccion_8/MMAF_python_8.ipynb).
#
#
# 3. La cantidad promedio de recursos entregados por comunidad después de $n$ días de operación se modela por:
#    $$
#    R(n) = 80\log(n+1) - \frac{n}{150}.
#    $$
#    - a) Calcule el límite de $R(n)$ cuando $n \to \infty$.
#    - b) Analice cómo evoluciona la distribución a largo plazo.
#    - c) Grafique $R(n)$ en el intervalo $n \in [1,1000]$ (Puede hacer uso de las herramientas presentadas en [MMAF\_python\_8.ipynb](https://colab.research.google.com/github/abelalv/PUJ_MMAF/blob/main/seccion_8/MMAF_python_8.ipynb).
#
#
# 4. La **eficiencia computacional** de un algoritmo de distribución está dada por:
#    $$
#    D(n) = \frac{n^2}{\ln(n+2)},
#    $$
#    mientras que la **demanda total** de recursos en cada nodo sigue la relación:
#    $$
#    Q(n) = n(\ln(n+2))^2.
#    $$
#    - a) Calcule el límite de $\dfrac{D(n)}{Q(n)}$ cuando $n \to \infty$.
#    - b) Interprete el resultado en términos de escalabilidad y eficiencia del sistema.
#
# 5. La función
#    $$
#    E(n) = \frac{5n^3 + 4n^2}{10n^3 - 3n + 7}
#    $$
#    describe la **eficiencia global** del sistema a medida que aumenta el número de comunidades atendidas.
#    - a) Calcule el límite de $E(n)$ cuando $n \to \infty$.
#    - b) Describa si el sistema tiende a estabilizarse o perder eficiencia.
#    - c) Verifique su respuesta mediante una gráfica. (Herramientas de graficación en [MMAF\_python\_8.ipynb](https://colab.research.google.com/github/abelalv/PUJ_MMAF/blob/main/seccion_8/MMAF_python_8.ipynb)
#
#
# 6. La función
#    $$
#    P(n) = \frac{500 + 20\sqrt{n}}{n + 10}
#    $$
#    representa el **promedio de personas atendidas por hora** a medida que crece el número de comunidades $n$.
#    - a) Calcule el límite de $P(n)$ cuando $n \to \infty$.
#    - b) Analice el comportamiento del sistema en el largo plazo.
#    - c) Grafique $P(n)$ en el intervalo $n \in [1,500]$ (Puede hacer uso de las herramientas presentadas en [MMAF\_python\_8.ipynb](https://colab.research.google.com/github/abelalv/PUJ_MMAF/blob/main/seccion_8/MMAF_python_8.ipynb).
#
#
# 7. La **cobertura relativa de recursos** frente al número de comunidades puede representarse por:
#    $$
#    C(n) = \frac{2n^2 + 50}{n^3 + 4n}.
#    $$
#    - a) Determine el límite de $C(n)$ cuando $n \to \infty$.
#    - b) Interprete el significado práctico de ese límite.
#    - c) Grafique $C(n)$ para visualizar cómo cambia la cobertura conforme aumenta $n$.
#
#
# 8. La **proporción de comunidades atendidas completamente** está modelada por:
#    $$
#    H(n) = \frac{n^2 + 3}{2n^2 + 5n + 8}.
#    $$
#    - a) Calcule el límite de $H(n)$ cuando $n \to \infty$.
#    - b) Interprete el valor obtenido en el contexto del sistema logístico.
#    - c) Grafique $H(n)$ en el rango $n \in [1,100]$ (Puede hacer uso de las herramientas presentadas en [MMAF\_python\_8.ipynb](https://colab.research.google.com/github/abelalv/PUJ_MMAF/blob/main/seccion_8/MMAF_python_8.ipynb).
#
#
# 9. La función
#    $$
#    E_r(n) = \frac{n}{(\ln n)^2}
#    $$
#    mide la **eficiencia relativa** de un algoritmo con respecto al número de nodos de distribución $n$.
#    - a) Determine para qué valor mínimo de $n$ se cumple que $E_r(n) \ge 100$.
#    - b) Use un método gráfico o de cálculo numérico para aproximar la respuesta (Puede hacer uso de las herramientas presentadas en [MMAF\_python\_8.ipynb](https://colab.research.google.com/github/abelalv/PUJ_MMAF/blob/main/seccion_8/MMAF_python_8.ipynb).
#    - c) Analice las implicaciones del resultado para el diseño de algoritmos más escalables.
