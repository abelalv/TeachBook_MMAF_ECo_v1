# %% [markdown]
# # Taller 2 de MMAF
#
# ## A Ejercicios de repaso
#
# ### A.1 Simplifique las siguientes expresiones:
#
#   1. $\left(\dfrac{x^6}{9y^{-4}}\right)^{-1/2}$
#
#   2. $\left(\dfrac{c^{-4}}{16d^8}\right)^{3/4}$
#
#   3. $\dfrac{(x^6y^3)^{-1/3}}{(x^4y^2)^{-1/2}}$
#
#   4. $a^{4/3}a^{-3/2}a^{1/6}$
#
# ### A.2 Reescriba la expresión usando exponentes racionales:
#
#   1. $\sqrt[3]{(a+b)^2}$
#
#   2. $\sqrt{a+\sqrt{b}}$
#
#   3. $\sqrt{x^2+y^2}$
#
#   4. $\sqrt[3]{r^3-s^3}$
#
# ### A.3 Realice las siguientes operaciones sobre polinomios:
#
#   1. $(3x^3+4x^2-7x+1)+(9x^3-4x^2-6x)$
#
#   2. $(7x^3+2x^2-11x)+(-3x^3-2x^2)$
#
#
# ### A.4 Multiplique los siguientes polinomios:
#
#   1. $(r^2-8r-2)(-r^2+3r-1)$
#   2. $(2x-1)(x^2-5)(x^3-1)$
#
# ### A.5 Calcule y simplifique:
#
#   1. $\dfrac{3u^3v^4-2u^5v^2+(u^2v^2)^2}{u^3v^2}$
#
#   2. $\dfrac{6x^2yz^3-xy^2z}{xyz}$
#
#   3. $(\sqrt{x}+\sqrt{y})^2(\sqrt{x}-\sqrt{y})^2$
#
#   4. $(x^{1/3}+y^{1/3})(x^{2/3}-x^{1/3}y^{1/3}+y^{2/3})$
#
# ### A.6 Factorice las expresiones:
#
#   1. $16x^5y^2+8x^3y^3$
#
#   2. $9y^4-121x^2$
#
#   3. $125x^3-8$
#
#   4. $x^6-27y^3$
#
#   5. $a^6-b^6$
#
# ### A.7 Factorice el polinomio:
#
#   1. $x^2+3x+4$
#
#   2. $4x^2-20x+25$
#
#   3. $25z^2+30z+9$
#
#   4. $50x^2+45xy-18y^2$
#
#   5. $2ay^2-axy+6xy-3x^2$
#
#   6. $5x^3+10x^2-20x-40$
#
#   7. $8c^6+19c^3-27$
#
# ### A.8 Simplifique la expresión:
#
#   1. $\dfrac{2x^2+9x-5}{3x^2+17x+10}$
#
#   2. $\dfrac{10+3r-r^2}{r^4+2r^3}$
#
#   3. $\dfrac{5}{x}-\dfrac{2x-1}{x^2}+\dfrac{x+5}{x^3}$
#
#   4. $\dfrac{2x+1}{x^2+4x+4}-\dfrac{6x}{x^2-4}+\dfrac{3}{x-2}$
#
#   5. $\dfrac{p^4+3p^3-8p-24}{p^3-2p^2-9p+18}$
#
# ### A.9 Simplifique la expresión:
#
#   1. $\dfrac{(x+h)^3+5(x+h)-(x^3+5x)}{h}$
#
#   2. $\dfrac{\dfrac{5}{2x+2h+3}-\dfrac{5}{2x+3}}{h}$
#
# ### A.10 Racionalice el denominador:
#   $$\dfrac{16x^2-y^2}{2\sqrt{x}-\sqrt{y}}$$
#
# ### A.11 Racionalice el numerador:
#   $$\dfrac{\sqrt{1-x-h}-\sqrt{1-x}}{h}$$
#
# ### A.12 Simplifique la expresión:
#   $$\dfrac{(3x+2)^{1/2}(\frac{1}{3})(2x+3)^{-2/3}(2)-(2x+3)^{1/3}(\frac{1}{2})(3x+2)^{-1/2}(3)}{[(3x+2)^{1/2}]^2}$$
#
# ### A.13 Problema de circuitos
#   En un problema particular de circuitos, el voltaje de salida está definido por $$V_{sal} = I_{ent}(-\frac{RXi}{R - Xi}),$$ donde $I_{ent} = \frac{V_{ent}}{Z_{ent}} $ y $ Z_{ent} = \frac{R^2 - X^2 - 3RXi}{R - Xi}.$ Encuentre una fórmula para $V_{sal} $ en términos de $V_{ent}$ cuando $R$ es igual a $X$.
#
# ### A.14 Optimización de Costos en la Fabricación de un Tanque Cilíndrico: Factorización en Ingeniería Industrial
#   *Contexto:*
#     Un ingeniero industrial está diseñando un tanque cilíndrico de almacenamiento de combustible con una base circular y sin tapa. Su objetivo es minimizar el costo de los materiales utilizados en la fabricación del tanque, lo cual depende del área superficial del cilindro. Para ello, debe factorizar una ecuación cuadrática que representa el costo de producción en función del radio del tanque.
#   *Problema:*
#     El costo total de fabricación del tanque está modelado por la ecuación: $$C(r) = r^2 + 6r - 16$$
#     donde:
#       - ( C(r) ) representa el costo de producción en miles de dólares.
#       - ( r ) es el radio del cilindro en metros.
#     Factoriza la ecuación del costo para determinar los valores críticos del radio.
#     Interpreta el resultado en términos de minimización de costos de fabricación.

# %% [markdown]
# ## B Ejercicios computacionales
#
# ### B.1
# Calcula las siguientes expresiones en python:
#
# 1. $\big(7\big)^{3/4}$
#
# 2. $\sqrt[3]{5}$
#
# 3. $\Big(-5\Big)^{4/3}$
#
# 4.  $\Big(-5\Big)^{3/4}$  **Que notas** en la salida del cálculo, ¿es correcto? Explica por qué.
#
# 5. $\Big(\frac{1}{3}\Big)^{-1/2}$
#
# **Note** que debes  manejar el uso de la potenciación con python [C.2.1](https://githubtocolab.com/abelalv/MMAF_2025/blob/main/seccion_2/MMAF_python_2.ipynb) para más información.
#
#
# ### B.2
#
# Efectúa las siguientes operaciones en python respetando la jerarquía de operaciones y verifica que el resultado coincide con el obtenido en papel.
#
# 1. $(5-3)^2\cdot\Big(6\cdot4+6\Big)$
#
# 2. $-\Big(4+5(-3-1)-4\Big)$
#
# 3.  $3\cdot\frac{7}{4}\div2+1$
#
# 4. $4\Big(\frac{3}{2}+4\Big(\frac{1-2}{2}\Big)\Big)^{1-3}$
#
# 5. $\Big(3\cdot\frac{1}{2-3}\Big)^2\cdot\Big(-2\cdot\frac{4-1}{3}\Big)^3$
#
# **Note** debes usar la función print para mostrar el resultado, puede ver la sección de [C.2.2](https://githubtocolab.com/abelalv/MMAF_2025/blob/main/seccion_2/MMAF_python_2.ipynb) para más información.
#
# ### B.3
#
# Aproxima  el volumen el de una caja con lados iguales y longitud  $e$, siendo $e$ la constante de Euler.
#
#
#
#
# **Note** debes usar la función print para mostrar el resultado, puede ver la sección de [C.2.3](https://githubtocolab.com/abelalv/MMAF_2025/blob/main/seccion_2/MMAF_python_2.ipynb) para ver el uso de constantes.
#
#
# ### B.4
#
# Aproxima el volumen de una esfera de radio $\pi$
#
# **Note** debes usar la función print para mostrar el resultado, puede ver la sección de [C.2.3](https://githubtocolab.com/abelalv/MMAF_2025/blob/main/seccion_2/MMAF_python_2.ipynnb) para ver el uso de constantes.
#
# ### B.5 Requerimientos de calorías
# El requerimiento de energía basal para una persona indica el número mínimo de calorías necesarias para mantener procesos esenciales de sostenimiento de la vida, como son circulación, regulación de la temperatura corporal y la respiración. Dado el sexo, peso $w$ (en kilogramos), estaura $h$ (en centímetros) y edad $y$ (en años) de una persona, podemos estimar el requerimiento de energía basal en calorpias usando las fórmulas siguentes donde $C_m$ y $C_h$ son las calorías necesarias para mujeres y hombres, respectivamente:
# $$C_m = 66.5 + 13.8w + 5h -6.8y$$
# $$C_h = 665 + 9.6w + 1.9h -4.7y$$
# (a) Determine los requerimientos de energía basal primero para una mujer de 25 años de edad que pesa 59 kilogramos, que mide 163 centímetros de estatura y luego para un hombre de 55 años de edad que pesa 75 kilogramos y mide 178 centímetros de estatura.
# (b) Explique por qué, en ambas formulas el coeficiente para $y$ es negativo pero los otros coeficientes son positivos.
#
# **Note** Debes solucionar este ejercicio de manera computacional.
