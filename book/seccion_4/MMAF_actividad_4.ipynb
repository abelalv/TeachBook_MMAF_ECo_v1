# %% [markdown]
# ## 4.1 Contexto

# %% [markdown]
# *Lotes, casas y su distribución*

# %% [markdown]
# La vivienda adecuada está reconocida como un derecho en los instrumentos internacionales incluidos la Declaración de los Derechos Humanos y el Pacto Internacional de los Derechos Económicos, Sociales y Culturales. La vivienda adecuada debe proveer más que cuatro paredes y un techo. Se deben cumplir una serie de condiciones particulares antes de considerarse como “Vivienda adecuada”.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La habitabilidad, siendo una de ellas, es la que garantiza la seguridad física de sus habitantes y les proporcionan un espacio habitable suficiente, así como protección contra el frío, la humedad, el calor, la lluvia, el viento u otros riesgos para la salud y peligros estructurales.
#
#  ![image.png](data:image/png;base64,...)
#
# (https://onu-habitat.org/index.php/elementos-de-una-vivienda-adecuada
# Consultado el 4 de noviembre de 2025.)

# %% [markdown]
# ## 4.2 Tema
#
# # Ecuación cuadrática
#
# ## 4.3  Objetivo
#
# Realizar la conversión de un problema en contexto de ecuación cuadrática representado en lengua natural a su representación numérica y algebraica.
#
# Establecer valores máximos y/o mínimos de una función cuadrática en un contexto determinado.
#
# Generalizar procesos y operaciones que impliquen el uso tanto de la ecuación como de la función cuadrática.

# %% [markdown]
# ## 4.4 Actividad
#
# Lea cuidadosamente la situación problema y resuelva las preguntas que se plantean a continuación. Debes escribir tus respuestas en la celda de texto que se encuentra debajo de cada pregunta. Si es necesario, puedes agregar celdas de código para realizar los cálculos que consideres pertinentes. Adicionalmente, puedes importar fotos de la formulaciones matemáticas que consideres necesarias para explicar tus respuestas.

# %% [markdown]
# ### 4.4.1 Una forma de organizar casas en un lote para su habitabilidad.
# Una empresa de construcción que esta empeñada en generar viviendas que cumplan con unos de los elementos de la vivenda acuada como es la habitabilidad está buscando un lote de 4896 metros cuadrados para construir 10 casas que ocupen, cada una, un lote rectangular de 8 metros de frente por 20 metros de largo. Si en este lote se deben distribuir las casas de tal manera que queden dos filas de cinco casas y que cumplan las siguientes condiciones:
# **(Otra posibilidad) 8 metros de largo por 20 de frente**
# •	Los lados laterales entre las casas deben quedar a igual distancia.
#
# •	Las casas que quedan de frente deben quedar al triple de la distancia que quedan lateralmente.
#
# •	Los lados laterales y posteriores de las casas que colindan con los bordes del lote de 4896 metros cuadrados deben quedar al doble de la distancia que quedan éstas lateralmente.
#
# a.	Grafique la situación,
#
# b.	Calcule las medidas del ancho y el largo del lote de 4896 metros cuadrados, las medidas de las diferentes distancias entre las casas y las medidas de las distancias entre las casas y los bordes del lote. Explique claramente el procedimiento utilizado para obtener la respuesta.

# %% [markdown]
# #### 4.4.1.1 Manos a la obra

# %% [markdown]
# 1. **Comprender el problema.** <span style="color:blue"> En esta etapa se busca comprender bien el problema que se quiere resolver e identificar las variables, datos y reglas relevantes para solucionar el problema. Descríbelos.</span>

# %% [markdown]
# 2. **Planear la solución.** <span style="color:blue">En esta etapa deberías identificar los pasos necesarios para resolver el problema y seleccionar la mejor estrategia para hacerlo.
#
# </span>

# %% [markdown]
# 3. **Ejecutar el plan.** <span style="color:blue"> En esta etapa deberías ejecutar la estrategia identificada en el paso anterior usando herramientas matemáticas, posiblemente asistidas por software. </span>

# %% [markdown]
# 4. **Examinar la solución obtenida** <span style="color:blue">Siempre que encuentres una solución de un problema es importante asegurarte que los resultados obtenido sean acordes  a las condiciones  iniciales del problema, factibles y en el caso contrario deberías regresar el primer paso.
# </span>

# %% [markdown]
# ### 4.4.2 Jugando con el computador!
#
# Considere lotes desde 1000 metros cuadrados hasta 20000 metros cuadrados, variando de 500 metros cuadrados en 500 metros cuadrados y calcule las diferentes distancias entre las casas. El siguiente programa, ingresando el área de un lote este arroja la distancia entre las casas y las medidas del lote total.

# %%
# importar Act4.py desde GitHub e importarlo
import requests

url = "https://raw.githubusercontent.com/Judival30/MMAF_ECO_lib/main/Act4.py"
txt = requests.get(url).text
open("Act4.py", "w").write(txt)

import Act4

# %%
Act4.solicitar_areas()
# Out:
# Ingrese áreas separadas por comas (ej: 2000,3000,5000): 1500,2000
#
# Gráfica generada: grafica_area_vs_x.png

# %% [markdown]
# ¿Cuáles serían las medias mínimas y máximas de un lote para poder construir las 10 casas de tal forma que cumplan con las condiciones dadas con una distancia razonable entre las casas?

# %% [markdown]
# #### 4.4.2.1 Manos a la obra

# %% [markdown]
# 1. **Comprender el problema.** <span style="color:blue"> En esta etapa se busca comprender bien el problema que se quiere resolver e identificar las variables, datos y reglas relevantes para solucionar el problema. Descríbelos.</span>

# %% [markdown]
# 2. **Planear la solución.** <span style="color:blue">En esta etapa deberías identificar los pasos necesarios para resolver el problema y seleccionar la mejor estrategia para hacerlo.
#
# </span>

# %% [markdown]
# 3. **Ejecutar el plan.** <span style="color:blue">En esta etapa deberías ejecutar la estrategia identificada en el paso anterior usando herramientas matemáticas, posiblemente asistidas por software.
#
# </span>

# %% [markdown]
# A continuación, encontrarás un programa que te permitirá introducir los datos del área y te generará las medidas de separación de las 10 casas al interior del lote del área dada.

# %% [markdown]
# 4. **Examinar la solución obtenida** <span style="color:blue"> Siempre que encuentres una solución de un problema es importante asegurarte que los resultados obtenido sean acordes  a las condiciones  iniciales del problema, factibles y en el caso contrario deberías regresar el primer paso.
# </span>
