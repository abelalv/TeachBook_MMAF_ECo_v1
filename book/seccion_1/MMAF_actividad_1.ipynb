# %% [markdown]
# # 1. Bitcoin Price Prediction

# %% [markdown]
# ## 1.1 Contexto

# %% [markdown]
# Las criptomonedas volvieron a ponerse de moda con el retorno de Donald Trump a la Casa Blanca. Y ahora el presidente argentino Javier Milei terminó en una tormenta mediática, y posiblemente jurídica, después de promocionar en redes sociales una cripto que terminó siendo una millonaria estafa.

# %% [markdown]
# ![bigcoin.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Se suponía que $Libra, el criptoactivo promovido por el mandatario y que era impulsado por la empresa KIP Protocol, ayudaría a las pequeñas y medianas empresas argentinas, pero en cuestión de horas empezó a generar sospechas de fraude y Milei terminó borrando su publicación y ordenando una “investigación urgente”. [Fuente: El colombiano. Consultado el 18 de febrero de 2025](https://www.elcolombiano.com/negocios/que-hay-detras-con-libra-criptomoneda-que-quebr-a-personas-en-argentina-NA26627857)

# %% [markdown]
# ## 1.2 Tema
#
# Notación científica y porcentajes
#
# ## 1.3  Objetivo
#
# Generalizar procedimientos de cálculo de porcentajes entre dos cantidades representadas en notación decimal y utilizar lenguajes de programación que permitan ahorrar tiempo en tales cálculos.
#
# Ordenar cantidades representadas en notación decimal sin el uso y con el uso lenguajes de programación.
#
# Realizar operaciones entre cantidades representadas en notación decimal usando lápiz y papel, calculadora y lenguajes de programación.

# %% [markdown]
# ## 1.4 Actividad
#
# Lea cuidadosamente la situación problema y resuelva las preguntas que se plantean a continuación. Debes escribir tus respuestas en la celda de texto que se encuentra debajo de cada pregunta. Si es necesario, puedes agregar celdas de código para realizar los cálculos que consideres pertinentes. Adicionalmente, puedes importar fotos de la formulaciones matemáticas que consideres necesarias para explicar tus respuestas.

# %% [markdown]
# ### 1.4.1 Una estrategia ingenua para invertir en Bitcoin
# Una criptomoneda es un tipo de moneda digital o virtual que utiliza criptografía para asegurar las transacciones y controlar la creación de nuevas unidades. A diferencia de las monedas tradicionales emitidas por los gobiernos (como el dólar o el euro), las criptomonedas operan en sistemas descentralizados basados generalmente en tecnología de cadena de bloques (blockchain).
#
# A continuación, se da una tabla donde se muestra el precio en dólares, mes a mes, desde octubre de 2024 a octubre a 2025 de la criptomoneda llamada BITCOIN.
#
# <div align="center">
#
# | Fecha       | Precio en dólares del BITCOIN |
# |--------------|-------------------------------:|
# | 01.10.2025   | 120 559.0                     |
# | 01.09.2025   | 114 048.5                     |
# | 01.08.2025   | 108 226.8                     |
# | 01.07.2025   | 115 765.0                     |
# | 01.06.2025   | 107 171.1                     |
# | 01.05.2025   | 104 598.0                     |
# | 01.04.2025   | 94 184.4                      |
# | 01.03.2025   | 82 548.8                      |
# | 01.02.2025   | 84 381.2                      |
# | 01.01.2025   | 94 536.1                      |
# | 01.12.2024   | 93 557.2                      |
# | 01.11.2024   | 96 405.7                      |
# | 01.10.2024   | 70 281.8                      |
#
#
# </div>
#
# Esta tabla nos permite comparar la variación del precio del BITCOIN y calcular el porcentaje con respecto al mes anterior, lo que nos puede ayudar a entender la tendencia del precio de la criptomoneda.
# Si se considera el cambio mes a mes en el precio del BITCOIN, ¿en qué periodo se presenta el mayor cambio entre los precios?¿En qué periodo se presenta el mayor porcentaje de cambio?
#  <span style="color:red"> Si usted, en ese periodo de tiempo, hubiera tenido 1000 dólares para invertir en BITCOIN, comprando en un mes y vendiendo en el siguiente ¿En qué fecha debería haber comprado para obtener mayor ganancia?¿En que fecha no debería haber comprado porque tendría la mayor pérdida ¿Que porcentaje de ganancia, o de pérdida, obtendría?  </span>

# %% [markdown]
# #### 1.4.1.1 Manos a la obra

# %% [markdown]
# 1. **Comprender el problema.** <span style="color:blue"> En esta etapa se busca comprender bien el problema que se quiere resolver e identificar las variables, datos y reglas relevantes para solucionar el problema. Descríbelos.</span>

# %% [markdown]
# 2. **Planear la solución.** <span style="color:blue">En esta etapa deberías identificar los pasos necesarios para resolver el problema y seleccionar la mejor estrategia para hacerlo.
#
# </span>

# %% [markdown]
# 3. **Ejecutar el plan.** <span style="color:blue"> En esta etapa deberías ejecutar la estrategia identificada en el paso anterior usando herramientas matemáticas, posiblemente asistidas por software. </span>

# %% [markdown]
# 4. **Examinar la solución obtenida** <span style="color:blue">Siempre que encuentres una solución de un problema es importante asegurarte que los resultados obtenido sean acordes  a las condiciones  iniciales del problema, factibles y en el caso contrario deberías regresar el primer paso.
# </span>

# %% [markdown]
# ### 1.4.2 Jugando con el computador!
#
# La siguiente tabla muestra el precio de cierre del BITCOIN en los últimos 20 días, el porcentaje de variación con respecto al día anterior. Además, se incluye un gráfico que muestra la evolución del precio de cierre del BITCOIN en ese período.
#
# <div align="center">
#
# | Fecha | Precio de Cierre | Variación |
# |-------|------------------|-----------|
# | 2025-09-27 | \$109 466.52 | N/A |
# | 2025-09-28 | \$111 866.96 | <span style="color:green">+2.19%</span> |
# | 2025-09-29 | \$114 387.96 | <span style="color:green">+2.25%</span> |
# | 2025-09-30 | \$114 214.15 | <span style="color:red">-0.15%</span> |
# | 2025-10-01 | \$118 774.17 | <span style="color:green">+3.99%</span> |
# | 2025-10-02 | \$120 366.33 | <span style="color:green">+1.34%</span> |
# | 2025-10-03 | \$122 291.07 | <span style="color:green">+1.60%</span> |
# | 2025-10-04 | \$123 864.55 | <span style="color:green">+1.29%</span> |
# | 2025-10-05 | \$123 952.58 | <span style="color:green">+0.07%</span> |
# | 2025-10-06 | \$124 338.76 | <span style="color:green">+0.31%</span> |
# | 2025-10-07 | \$121 342.42 | <span style="color:red">-2.41%</span> |
# | 2025-10-08 | \$122 040.70 | <span style="color:green">+0.58%</span> |
# | 2025-10-09 | \$121 139.15 | <span style="color:red">-0.74%</span> |
# | 2025-10-10 | \$112 320.58 | <span style="color:red">-7.28%</span> |
# | 2025-10-11 | \$110 809.93 | <span style="color:red">-1.34%</span> |
# | 2025-10-12 | \$114 822.19 | <span style="color:green">+3.62%</span> |
# | 2025-10-13 | \$113 637.98 | <span style="color:red">-1.03%</span> |
#
#
# </div>

# %%
# %%writefile cryptoPlot.py
import requests  # Corregido: se quitó el #
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

def cargarDatos(fecha_inicio=None, fecha_fin=None):
    """
    Obtiene los precios de cierre de Bitcoin según tres posibles casos:
     Sin parámetros: usa la fecha actual y obtiene los últimos 30 días.
     Con una sola fecha: usa esa fecha como final y obtiene los últimos 30 días.
     Con rango de fechas: usa ambas fechas proporcionadas.
    """
    try:
        # Caso 1: Sin parámetros (últimos 30 días desde hoy)
        if fecha_inicio is None and fecha_fin is None:
            fecha_fin = datetime.now()
            fecha_inicio = fecha_fin - timedelta(days=30)

        # Caso 2: Una sola fecha (se interpreta como fecha FINAL)
        elif fecha_inicio is not None and fecha_fin is None:
            fecha_fin_dt = datetime.strptime(fecha_inicio, "%Y-%m-%d")
            fecha_fin = fecha_fin_dt
            fecha_inicio = fecha_fin - timedelta(days=30)

        # Caso 3: Dos fechas (Rango específico)
        elif fecha_inicio is not None and fecha_fin is not None:
            fecha_inicio = datetime.strptime(fecha_inicio, "%Y-%m-%d")
            fecha_fin = datetime.strptime(fecha_fin, "%Y-%m-%d")

        ts_inicio = int(fecha_inicio.timestamp())
        ts_fin = int(fecha_fin.timestamp())

        # URL y parámetros
        url = "https://api.coingecko.com/api/v3/coins/bitcoin/market_chart/range"
        params = {
            'vs_currency': 'usd',
            'from': ts_inicio,
            'to': ts_fin
        }

        print(f"Obteniendo datos de Bitcoin desde {fecha_inicio.date()} hasta {fecha_fin.date()}...")
        r = requests.get(url, params=params, timeout=10)
        r.raise_for_status()

        data = r.json()
        precios = data.get('prices', [])
        if not precios:
            print("No hay datos disponibles en el rango solicitado.")
            return None

        # Procesar datos
        registros = []
        for p in precios:
            fecha = datetime.fromtimestamp(p[0] / 1000)
            valor = p[1]
            registros.append({'fecha': fecha.date(), 'precio_cierre': valor})

        df = pd.DataFrame(registros)
        df = df.groupby('fecha')['precio_cierre'].last().reset_index()
        df['variacion_porcentual'] = df['precio_cierre'].pct_change() * 100

        return df

    except requests.exceptions.RequestException as e:
        print(f"Error de conexión: {e}")
        return None
    except Exception as e:
        print(f"Error inesperado: {e}")
        return None

def mostrar_datos_bitcoin(datos):
    """
    Muestra los datos de Bitcoin y genera gráficos.
    """
    if datos is None or datos.empty:
        print("No se pudieron obtener datos para graficar.")
        return
        
    # Configuración de Gráficos 
    plt.figure(figsize=(14, 8))

    # Subplot 1: precios
    ax1 = plt.subplot(2, 1, 1)
    ax1.plot(datos['fecha'], datos['precio_cierre'],
             color='blue', linewidth=2.5, label='Precio de Cierre')
    ax1.scatter(datos['fecha'], datos['precio_cierre'],
                color='red', s=60, zorder=5, label='Puntos de Cierre')
    ax1.set_title('Precio de Cierre de Bitcoin', fontsize=16, fontweight='bold', pad=20)
    ax1.set_ylabel('Precio (USD)', fontsize=12)
    ax1.grid(True, alpha=0.3)
    ax1.legend()
    # Formateador de moneda simple para evitar errores si FuncFormatter falla
    ax1.tick_params(axis='x', rotation=45)

    # Subplot 2: variación porcentual
    ax2 = plt.subplot(2, 1, 2)
    # Corrección para evitar error si la data es muy corta
    if len(datos) > 1:
        colores = ['green' if v >= 0 else 'red' for v in datos['variacion_porcentual'].iloc[1:]]
        eje_x = datos['fecha'].iloc[1:]
        altura_barras = datos['variacion_porcentual'].iloc[1:]
        
        barras = ax2.bar(eje_x, altura_barras, color=colores, alpha=0.7, label='Variación Diaria')
        
        # Etiquetas 
        for barra in barras:
            altura = barra.get_height()
            va = 'bottom' if altura >= 0 else 'top'
            color_text = 'green' if altura >= 0 else 'red'
            ax2.text(barra.get_x() + barra.get_width()/2., altura,
                     f'{altura:+.1f}%', ha='center', va=va, fontweight='bold', color=color_text, fontsize=8)
    
    ax2.set_title('Variación Porcentual Diaria', fontsize=14, fontweight='bold', pad=20)
    ax2.set_xlabel('Fecha', fontsize=12)
    ax2.set_ylabel('Variación (%)', fontsize=12)
    ax2.grid(True, alpha=0.3)
    ax2.axhline(y=0, color='black', linestyle='-', alpha=0.8)
    plt.setp(ax2.xaxis.get_majorticklabels(), rotation=45)

    plt.tight_layout()
    plt.show()

def mostrar_tabla_bitcoin(datos):
    """ Muestra la tabla visual """
    if datos is None or datos.empty:
        print("No se pudieron obtener datos para la tabla.")
        return

    tabla = datos.copy()
    tabla['fecha'] = tabla['fecha'].astype(str)
    tabla['precio_cierre'] = tabla['precio_cierre'].apply(lambda x: f"${x:,.2f}")
    tabla['variacion_porcentual'] = tabla['variacion_porcentual'].apply(
        lambda x: f"{x:+.2f}%" if pd.notna(x) else "N/A"
    )

    columnas = ['Fecha', 'Precio de Cierre', 'Variación %']
    celdas = tabla.values.tolist()

    fig, ax = plt.subplots(figsize=(10, len(tabla) * 0.45 + 1))
    ax.axis('off')
    
    tabla_visual = ax.table(
        cellText=celdas,
        colLabels=columnas,
        loc='center',
        cellLoc='center',
        colColours=["#000A66", "#003366", "#003366"],  
        edges='closed'
    )
    
    tabla_visual.auto_set_font_size(False)
    tabla_visual.set_fontsize(10)
    tabla_visual.scale(1.2, 1.3)
    ax.set_title("Evolución del Precio de Cierre", fontsize=14, fontweight='bold', pad=20)
    plt.show()
    # 1. Instalar las librerías necesarias en el entorno del navegador
%pip install requests pyodide-http

# 2. Configurar el parche para que requests funcione en JupyterLite
import pyodide_http
pyodide_http.patch_all()  # Esto hace que requests.get funcione en el navegador

# 3. Ahora sí, recargar y ejecutar tu librería
import cryptoPlot as cp
import importlib

# Recargamos para asegurar que tome los cambios
importlib.reload(cp)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import micropip
#       2 await micropip.install("pandas")
#
# ModuleNotFoundError: No module named 'micropip'

# %%
# 1. Primero obtén los datos con cargarDatos():
#    - Sin parámetros: últimos 30 días hasta hoy
#         datos = cargarDatos()
#    - Con una sola fecha (fin): últimos 30 días hasta esa fecha
#         datos = cargarDatos("2025-10-01")
#    - Con rango de fechas (inicio y fin):
#         datos = cargarDatos("2025-09-01", "2025-09-25")
#
# 2. Para ver los gráficos de precio y variación diaria:
#         mostrar_datos_bitcoin(datos)
#
# 3. Para ver la tabla bonita con precios y variaciones:
#         mostrar_tabla_bitcoin(datos)

# Probamos la función
print("Intentando obtener datos...")
datos = cp.cargarDatos("2025-10-13")
cp.mostrar_datos_bitcoin(datos)
# Out:
# Obteniendo datos de Bitcoin desde 2025-09-13 hasta 2025-10-13...

# %%
cp.mostrar_tabla_bitcoin(datos)

# %% [markdown]
# En muchas ocasiones los inversionistas de criptomonedas, invierten su dinero por periodos cortos de tiempo, por ejemplo 20 días. Aunque los inversionistas revisan todos los días la ganancia acumulada y muchos de ellos toman decisiones basadas en esta información; por ejemplo, si la pérdida es significativa, es decir supera el 5%  del precio de compra; ellos prefieren vender que mantener la inversión. Suponga que usted sabe de antemano el precio de cierre del BITCOIN de 20 días consecutivos, desde el día 2025-09-27 hasta el día 2025-10-13,y va hacer una inversión de $100,000. <span style="color:red"> ¿cuanto ganaría, si usted hubiera vendido en el momento adecuado?</span>

# %% [markdown]
# #### 1.4.2.1 Manos a la obra

# %% [markdown]
# 1. **Comprender el problema.** <span style="color:blue"> En esta etapa se busca comprender bien el problema que se quiere resolver e identificar las variables, datos y reglas relevantes para solucionar el problema. Descríbelos.</span>

# %% [markdown]
# 2. **Planear la solución.** <span style="color:blue">En esta etapa deberías identificar los pasos necesarios para resolver el problema y seleccionar la mejor estrategia para hacerlo.
#
# </span>

# %% [markdown]
# 3. **Ejecutar el plan.** <span style="color:blue">En esta etapa deberías ejecutar la estrategia identificada en el paso anterior usando herramientas matemáticas, posiblemente asistidas por software.
#
# </span>

# %% [markdown]
# 4. **Examinar la solución obtenida** <span style="color:blue"> Siempre que encuentres una solución de un problema es importante asegurarte que los resultados obtenido sean acordes  a las condiciones  iniciales del problema, factibles y en el caso contrario deberías regresar el primer paso.
# </span>
